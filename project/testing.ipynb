# %%
from recomm_dataset import load_scidocs_cite, scidoc_cite_to_triplets

# %%
test = load_scidocs_cite()["validation"]
# Out:
# ...
# Loading dataset shards:   0%|          | 0/48 [00:00<?, ?it/s]

# %%
mapped = scidoc_cite_to_triplets(test)

# %%
mapped.shard(10, 0)
# Out:
# Dataset({
#     features: ['query', 'pos', 'neg'],
#     num_rows: 17643
# })

# %%
scidoc_cite_to_triplets(load_scidocs_cite()["train"].shard(100, 0))
# Out:
# ...
# Map:   0%|          | 0/61980 [00:00<?, ? examples/s]
# Dataset({
#     features: ['query', 'pos', 'neg'],
#     num_rows: 61980
# })
